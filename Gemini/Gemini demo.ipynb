# %%
import os
from dotenv import load_dotenv

# %%
import google.generativeai as genai
from IPython.display import Image
# Load environment variables from .env file
load_dotenv()

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

img = Image("img1.png")
display(img)

# %%
model = genai.GenerativeModel(model_name="gemini-1.5-flash")
response = model.generate_content(["Can you explain this picture?", img])
print(response.text)
# Out:
# The picture shows a green grassy hill with a blue sky and white clouds in the background. It looks similar to the default desktop background for Windows operating systems. It's a simple, iconic image that evokes a sense of serenity and tranquility.
